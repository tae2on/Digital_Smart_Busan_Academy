# %%
import urllib.request

# %%
client_id = "0mpuAT0qbT45zRys5VU7"
client_secret = "5DDLULrpfz"

# %%
print(client_id + '\n' + client_secret)
# Out:
# 0mpuAT0qbT45zRys5VU7
# 5DDLULrpfz

# %%
encText = urllib.parse.quote("동의대학교")
print(encText)
# Out:
# %EB%8F%99%EC%9D%98%EB%8C%80%ED%95%99%EA%B5%90

# %%
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
print(url)
# Out:
# https://openapi.naver.com/v1/search/blog?query=%EB%8F%99%EC%9D%98%EB%8C%80%ED%95%99%EA%B5%90

# %%
request = urllib.request.Request(url)
request

# %%
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# %%
request

# %%
response = urllib.request.urlopen(request)
response

# %%
rescode = response.getcode()
rescode
# Out:
# 200

# %%
response_body = response.read()
response_body
# Out:
# b'{\n\t"lastBuildDate":"Wed, 19 Jul 2023 14:20:06 +0900",\n\t"total":32686,\n\t"start":1,\n\t"display":10,\n\t"items":[\n\t\t{\n\t\t\t"title":"[\xeb\xb6\x80\xec\x82\xb0 \\/ \xeb\xb6\x80\xec\x82\xb0\xec\xa7\x84\xea\xb5\xac] <b>\xeb\x8f\x99\xec\x9d\x98\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90<\\/b> \xeb\xb0\x94\xeb\xa1\x9c\xec\x95\x9e \xea\xb0\x80\xec\x95\xbc\xeb\x8f\x99 \xed\x8f\xac\xeb\xa0\x88\xeb\x82\x98 \xec\x9b\x90\xeb\xa3\xb8... ",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/rldrlddl2\\/223136936576",\n\t\t\t"description":"\xec\x98\xa4\xeb\x8a\x98 \xeb\xb3\xb4\xec\x97\xac\xeb\x93\x9c\xeb\xa6\xb4 \xeb\xa7\xa4\xeb\xac\xbc\xec\x9d\x80 \xea\xb0\x80\xec\x95\xbc\xeb\x8f\x99 <b>\xeb\x8f\x99\xec\x9d\x98\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90<\\/b> \xec\x9d\xb8\xea\xb7\xbc\xec\x97\x90 \xec\x9c\x84\xec\xb9\x98\xed\x95\x9c \xec\x9b\x90\xeb\xa3\xb8 \xeb\xa7\xa4\xeb\xac\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4. \xec\x9b\x94\xec\x84\xb8\xeb\xa1\x9c \xeb\xb3\xb4\xec\xa6\x9d\xea\xb8\x88 \xec\xa1\xb0\xec\
# ...

# %%
print(response_body.decode('utf-8'))
# Out:
# {
# 	"lastBuildDate":"Wed, 19 Jul 2023 14:20:06 +0900",
# 	"total":32686,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"[부산 \/ 부산진구] <b>동의대학교<\/b> 바로앞 가야동 포레나 원룸... ",
# 			"link":"https:\/\/blog.naver.com\/rldrlddl2\/223136936576",
# 			"description":"오늘 보여드릴 매물은 가야동 <b>동의대학교<\/b> 인근에 위치한 원룸 매물입니다. 월세로 보증금 조절은 가능하며 <b>동의대학교<\/b> 학생분들게 인기가 많은 곳이기도 합니다. 이유는 고층이며 신축에 채광이 너무... ",
# 			"bloggername":"♥HELLO HOUSE♥",
# 			"bloggerlink":"blog.naver.com\/rldrlddl2",
# 			"postdate":"20230623"
# 		},
# 		{
# 			"title":"동의대 편입 준비해서 <b>동의대학교<\/b>에 입학",
# 			"link":"https:\/\/blog.naver.com\/pants11649\/223089282011",
# 			"description":"안녕하세요 이번 시간에는 동의대 편입을 준비해서 <b>동의대학교<\/b>에 입학할 수 있었던 과정에 대해 알아보려고 하는데요 부산에 위치한 동의대에도 경찰행정 방사선 간호학과 등 다양한 학과가 개설되어 있는... ",
# 			"bloggername":"어쩌다 공부",
# 			"bloggerlink":"blog.naver.com\/pants11649",
# 			"postdate":"20230430"
# 		},
# 		{
# 			"title":"<b>동의대학교<\/b> 정시등급(22) 표준점수 합 수시 충원합격 후보순위",
# ...

# %%
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %%
# display = 100으로 수정
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=100"# JSON 결과
print(url)
# Out:
# https://openapi.naver.com/v1/search/blog?query=%EB%8F%99%EC%9D%98%EB%8C%80%ED%95%99%EA%B5%90&display=100

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 19 Jul 2023 14:23:55 +0900",
# 	"total":32686,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"[부산 \/ 부산진구] <b>동의대학교<\/b> 바로앞 가야동 포레나 원룸... ",
# 			"link":"https:\/\/blog.naver.com\/rldrlddl2\/223136936576",
# 			"description":"오늘 보여드릴 매물은 가야동 <b>동의대학교<\/b> 인근에 위치한 원룸 매물입니다. 월세로 보증금 조절은 가능하며 <b>동의대학교<\/b> 학생분들게 인기가 많은 곳이기도 합니다. 이유는 고층이며 신축에 채광이 너무... ",
# 			"bloggername":"♥HELLO HOUSE♥",
# 			"bloggerlink":"blog.naver.com\/rldrlddl2",
# 			"postdate":"20230623"
# 		},
# 		{
# 			"title":"동의대 편입 준비해서 <b>동의대학교<\/b>에 입학",
# 			"link":"https:\/\/blog.naver.com\/pants11649\/223089282011",
# 			"description":"안녕하세요 이번 시간에는 동의대 편입을 준비해서 <b>동의대학교<\/b>에 입학할 수 있었던 과정에 대해 알아보려고 하는데요 부산에 위치한 동의대에도 경찰행정 방사선 간호학과 등 다양한 학과가 개설되어 있는... ",
# 			"bloggername":"어쩌다 공부",
# 			"bloggerlink":"blog.naver.com\/pants11649",
# 			"postdate":"20230430"
# 		},
# 		{
# 			"title":"<b>동의대학교<\/b> 정시등급(22) 표준점수 합 수시 충원합격 후보순위",
# ...

# %%
# start = 2으로 수정
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=100" + "&start=2"# JSON 결과
print(url)
# Out:
# https://openapi.naver.com/v1/search/blog?query=%EB%8F%99%EC%9D%98%EB%8C%80%ED%95%99%EA%B5%90&display=100&start=2

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 19 Jul 2023 14:26:32 +0900",
# 	"total":32686,
# 	"start":2,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"동의대 편입 준비해서 <b>동의대학교<\/b>에 입학",
# 			"link":"https:\/\/blog.naver.com\/pants11649\/223089282011",
# 			"description":"안녕하세요 이번 시간에는 동의대 편입을 준비해서 <b>동의대학교<\/b>에 입학할 수 있었던 과정에 대해 알아보려고 하는데요 부산에 위치한 동의대에도 경찰행정 방사선 간호학과 등 다양한 학과가 개설되어 있는... ",
# 			"bloggername":"어쩌다 공부",
# 			"bloggerlink":"blog.naver.com\/pants11649",
# 			"postdate":"20230430"
# 		},
# 		{
# 			"title":"<b>동의대학교<\/b> 정시등급(22) 표준점수 합 수시 충원합격 후보순위",
# 			"link":"https:\/\/blog.naver.com\/kmimi77\/222967268073",
# 			"description":"<b>동의대학교<\/b> 정시등급(2) 표준점수 합 수시 충원합격 후보순위 23학년도 수시모집 충원합격 9차(최종)... 학생부종합 학교생활우수자 동의대 수시등급 및 추가합격 예비순위 입결을 확인해 보면... ",
# 			"bloggername":"go Edu",
# 			"bloggerlink":"blog.naver.com\/kmimi77",
# 			"postdate":"20221227"
# 		},
# 		{
# 			"title":"일광신도시 다시보자!(<b>동의대학교<\/b> 신입생모집)",
# 			"link":"https:\/\/blog.naver.com\/pmh2282\/222464481796",
# ...

# %%
text = response_body.decode('utf-8')

# %%
temp = []

# %%
temp.append(text)

# %%
temp
# Out:
# ['{\n\t"lastBuildDate":"Wed, 19 Jul 2023 14:26:32 +0900",\n\t"total":32686,\n\t"start":2,\n\t"display":100,\n\t"items":[\n\t\t{\n\t\t\t"title":"동의대 편입 준비해서 <b>동의대학교<\\/b>에 입학",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/pants11649\\/223089282011",\n\t\t\t"description":"안녕하세요 이번 시간에는 동의대 편입을 준비해서 <b>동의대학교<\\/b>에 입학할 수 있었던 과정에 대해 알아보려고 하는데요 부산에 위치한 동의대에도 경찰행정 방사선 간호학과 등 다양한 학과가 개설되어 있는... ",\n\t\t\t"bloggername":"어쩌다 공부",\n\t\t\t"bloggerlink":"blog.naver.com\\/pants11649",\n\t\t\t"postdate":"20230430"\n\t\t},\n\t\t{\n\t\t\t"title":"<b>동의대학교<\\/b> 정시등급(22) 표준점수 합 수시 충원합격 후보순위",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/kmimi77\\/222967268073",\n\t\t\t"description":"<b>동의대학교<\\/b> 정시등급(2) 표준점수 합 수시 충원합격 후보순위 23학년도 수시모집 충원합격 9차(최종)... 학생부종합 학교생활우수자 동의대 수시등급 및 추가합격 예비순위 입결을 확인해 보면... ",\n\t\t\t"bloggername":"go Edu",\n\t\t\t"bloggerlink":"blog.naver.com\\/kmimi77",\n\t\t\t"postdate":"20221227"\n\t\t},\n\t\t{\n\t\t\t"title":"일광신도시 다시보자!(<b>동의대학교<\\/b> 신입생모집)",\n\t\t\t"link":"https:\\/\\/
# ...

# %%
import urllib.request
import time

client_id = "0mpuAT0qbT45zRys5VU7"
client_secret = "5DDLULrpfz"
encText = urllib.parse.quote("동의대학교")
lst = []

for i in range(1, 1000, 100):
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=100" + "&start=" + str(i)  # JSON 결과
       # f'{i} 대신에 str(i)로도 수정 가능
#print(url + f'{i}' + "-" + f'{i + 99}')

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    time.sleep(0.1)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        lst.append(response_body.decode('utf-8'))
        print(lst)
    else:
        print("Error Code:" + rescode)
# Out:
# ['{\n\t"lastBuildDate":"Wed, 19 Jul 2023 15:50:24 +0900",\n\t"total":32688,\n\t"start":1,\n\t"display":100,\n\t"items":[\n\t\t{\n\t\t\t"title":"[부산 \\/ 부산진구] <b>동의대학교<\\/b> 바로앞 가야동 포레나 원룸... ",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/rldrlddl2\\/223136936576",\n\t\t\t"description":"오늘 보여드릴 매물은 가야동 <b>동의대학교<\\/b> 인근에 위치한 원룸 매물입니다. 월세로 보증금 조절은 가능하며 <b>동의대학교<\\/b> 학생분들게 인기가 많은 곳이기도 합니다. 이유는 고층이며 신축에 채광이 너무... ",\n\t\t\t"bloggername":"♥HELLO HOUSE♥",\n\t\t\t"bloggerlink":"blog.naver.com\\/rldrlddl2",\n\t\t\t"postdate":"20230623"\n\t\t},\n\t\t{\n\t\t\t"title":"동의대 편입 준비해서 <b>동의대학교<\\/b>에 입학",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/pants11649\\/223089282011",\n\t\t\t"description":"안녕하세요 이번 시간에는 동의대 편입을 준비해서 <b>동의대학교<\\/b>에 입학할 수 있었던 과정에 대해 알아보려고 하는데요 부산에 위치한 동의대에도 경찰행정 방사선 간호학과 등 다양한 학과가 개설되어 있는... ",\n\t\t\t"bloggername":"어쩌다 공부",\n\t\t\t"bloggerlink":"blog.naver.com\\/pants11649",\n\t\t\t"postdate":"20230430"\n\t\t},\n\t\t{\n\t\t\t"title":"<b>동의대학교<\\/b> 정시등급(22) 표준점수 합 수시 충원합격 
# ...

# %%
import time
import urllib.request
client_id = "0mpuAT0qbT45zRys5VU7"
client_secret = "5DDLULrpfz"
encText = urllib.parse.quote("검색할 단어")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
time.sleep(0.1)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 19 Jul 2023 14:56:29 +0900",
# 	"total":931197,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"직장인이 최근 많이 <b>검색<\/b>한 <b>단어<\/b>",
# 			"link":"https:\/\/blog.naver.com\/blueyoungman\/223099437889",
# 			"description":"- 직장인이라면 한 번쯤 머릿속을 스쳐간 <b>단어<\/b>가 있을 것이다. '권고사직'이다. 권고사직이... 직장인 소셜 플랫폼 블라인드에서 권고사직을 <b>검색<\/b>한 직장인이 1년만에 9배 이상 증가한 것으로 나타났다.... ",
# 			"bloggername":"재테크와 일상 그 어딘가.",
# 			"bloggerlink":"blog.naver.com\/blueyoungman",
# 			"postdate":"20230511"
# 		},
# 		{
# 			"title":"아이폰 사파리 텍스트 찾기 <b>단어<\/b> <b>검색<\/b> 방법 정리",
# 			"link":"https:\/\/blog.naver.com\/jhbksgi\/222982804031",
# 			"description":"아이폰 사파리 크롬 텍스트 찾기 <b>단어<\/b> <b>검색<\/b> 방법 정리 글\/사진 : 곰T 기본적으로 컴퓨터용, 모바일용 Browser에는 '<b>검색<\/b>' 기능이 있습니다. 그냥 <b>검색<\/b>(Search)이라고 하면 감이 잘 오지 않을 수 있겠네요. 좀 더... ",
# 			"bloggername":"곰T의 IT트러블슈팅",
# 			"bloggerlink":"blog.naver.com\/jhbksgi",
# 			"postdate":"20230112"
# 		},
# 		{
# ...
