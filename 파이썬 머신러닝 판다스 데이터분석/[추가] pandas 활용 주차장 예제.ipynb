# %%
import pandas as pd
df_car = pd.read_excel('c:/sample_data/car_in_seoul.xls',
                      header=1,
                      usecols='A, B, C, G, K, O, S')
df_car.head()
# Out:
#      기간  자치구       소계     소계.1    소계.2    소계.3  소계.4
# 0  2017  서울시  3116256  2641190  127564  339921  7581
# 1  2017  종로구    50828    41115    4055    5469   189
# 2  2017   중구    51540    40523    3508    7294   215
# 3  2017  용산구    77458    67335    2783    7221   119
# 4  2017  성동구   103116    87762    3698   11459   197

# %%
df_par = pd.read_excel('c:/sample_data/par_in_seoul.xls',
                      header=1,
                      usecols='A, B, C, I, O, W')
df_par.head()
# Out:
#      기간  자치구       계   계.2   계.4     계.6
# 0    기간  자치구      개소    개소    개소      개소
# 1  2017  서울시  308025  8576  1977  297472
# 2  2017  종로구    7220   148   103    6969
# 3  2017   중구    4152   151    94    3907
# 4  2017  용산구    7291   362    75    6854

# %%
df_car.rename(columns={df_car.columns[0]: "년도",
                      df_car.columns[1]: "자치구",
                      df_car.columns[2]: "합계",
                      df_car.columns[3]: "승용차",
                      df_car.columns[4]: "승합차",
                      df_car.columns[5]: "화물차",
                      df_car.columns[6]: "특수차"},
                      inplace=True)
df_car.head()
# Out:
#      년도  자치구       합계      승용차     승합차     화물차   특수차
# 0  2017  서울시  3116256  2641190  127564  339921  7581
# 1  2017  종로구    50828    41115    4055    5469   189
# 2  2017   중구    51540    40523    3508    7294   215
# 3  2017  용산구    77458    67335    2783    7221   119
# 4  2017  성동구   103116    87762    3698   11459   197

# %%
df_par.rename(columns={df_par.columns[0]: "년도",
                      df_par.columns[1]: "자치구",
                      df_par.columns[2]: "합계",
                      df_par.columns[3]: "노상",
                      df_par.columns[4]: "노외",
                      df_par.columns[5]: "건축물부설"},
                      inplace=True)
df_par.head()
# Out:
#      년도  자치구      합계    노상    노외   건축물부설
# 0    기간  자치구      개소    개소    개소      개소
# 1  2017  서울시  308025  8576  1977  297472
# 2  2017  종로구    7220   148   103    6969
# 3  2017   중구    4152   151    94    3907
# 4  2017  용산구    7291   362    75    6854

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      27 non-null     int64
#  1   자치구     27 non-null     object
#  2   합계      27 non-null     object
#  3   승용차     27 non-null     object
#  4   승합차     27 non-null     object
#  5   화물차     27 non-null     object
#  6   특수차     27 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.6+ KB

# %%
df_par.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      27 non-null     object
#  1   자치구     27 non-null     object
#  2   합계      27 non-null     object
#  3   노상      27 non-null     object
#  4   노외      27 non-null     object
#  5   건축물부설   27 non-null     object
# dtypes: object(6)
# memory usage: 1.4+ KB

# %%
df_car
# Out:
#       년도   자치구       합계      승용차     승합차     화물차   특수차
# 0   2017   서울시  3116256  2641190  127564  339921  7581
# 1   2017   종로구    50828    41115    4055    5469   189
# 2   2017    중구    51540    40523    3508    7294   215
# 3   2017   용산구    77458    67335    2783    7221   119
# 4   2017   성동구   103116    87762    3698   11459   197
# 5   2017   광진구    98631    82951    4169   11248   263
# 6   2017  동대문구    97507    79837    4249   13244   177
# 7   2017   중랑구   113916    92596    5305   15619   396
# 8   2017   성북구   117209   100028    5745   11311   125
# 9   2017   강북구    77820    63987    4268    9416   149
# 10  2017   도봉구    97323    82048    4129   10937   209
# 11  2017   노원구   154708   134400    6291   13708   309
# 12  2017   은평구   129004   109372    5745   13636   251
# 13  2017  서대문구    86068    73356    3646    8764   302
# 14  2017   마포구   116531    99278    4662   12352   239
# 15  2017   양천구   150823   128605    5648   16034   536
# ...

# %%
df_par
# Out:
#       년도   자치구      합계    노상    노외   건축물부설
# 0     기간   자치구      개소    개소    개소      개소
# 1   2017   서울시  308025  8576  1977  297472
# 2   2017   종로구    7220   148   103    6969
# 3   2017    중구    4152   151    94    3907
# 4   2017   용산구    7291   362    75    6854
# 5   2017   성동구    6658   264    65    6329
# 6   2017   광진구   16304   359    70   15875
# 7   2017  동대문구    9485    30    57    9398
# 8   2017   중랑구   12170   525    81   11564
# 9   2017   성북구   13038   125   154   12759
# 10  2017   강북구   10528    23    59   10446
# 11  2017   도봉구    9593   460    61    9072
# 12  2017   노원구    6612   154    45    6413
# 13  2017   은평구   19119   109    82   18928
# 14  2017  서대문구   11835   626    96   11113
# 15  2017   마포구   13905    29    87   13789
# 16  2017   양천구   11811   488    56   11267
# 17  2017   강서구   18630   696    56   17878
# 18  2017   구로구   10219   299    58    9862
# 19  2017   금천구    9393    33    53    9307
# 20  2017  영등포구   10018  2177    69    7772
# ...

# %%
df_car.drop([0], inplace=True)   # 자동차 서울시 제거
df_car.drop([26], inplace=True)   # 자동차 기타 제거
df_par.drop([0], inplace=True)   # 주차장 서울시 제거

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      25 non-null     int64
#  1   자치구     25 non-null     object
#  2   합계      25 non-null     object
#  3   승용차     25 non-null     object
#  4   승합차     25 non-null     object
#  5   화물차     25 non-null     object
#  6   특수차     25 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.5+ KB

# %%
df_par.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 1 to 26
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      26 non-null     object
#  1   자치구     26 non-null     object
#  2   합계      26 non-null     object
#  3   노상      26 non-null     object
#  4   노외      26 non-null     object
#  5   건축물부설   26 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB

# %%
# 컬럼 데이터 형식 변환
df_car['합계'] = df_car['합계'].astype(int)
df_car['승용차'] = df_car['승용차'].astype(int)
df_car['승합차'] = df_car['승합차'].astype(int)
df_car['화물차'] = df_car['화물차'].astype(int)
df_car['특수차'] = df_car['특수차'].astype(int)
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      25 non-null     int64
#  1   자치구     25 non-null     object
#  2   합계      25 non-null     int32
#  3   승용차     25 non-null     int32
#  4   승합차     25 non-null     int32
#  5   화물차     25 non-null     int32
#  6   특수차     25 non-null     int32
# dtypes: int32(5), int64(1), object(1)
# memory usage: 1.0+ KB

# %%
#df_car에 
# 승용차비율, 승합차비율, 화물차비율
# 계산필드 추가
df_car['승용차 비율'] = (df_car['승용차']/df_car['합계']) * 100
df_car['승합차 비율'] = (df_car['승합차']/df_car['합계']) * 100
df_car['화물차 비율'] = (df_car['화물차']/df_car['합계']) * 100
df_car.head(10)
# Out:
#       년도   자치구      합계     승용차   승합차    화물차  특수차     승용차 비율    승합차 비율  \
# 1   2017   종로구   50828   41115  4055   5469  189  80.890454  7.977886
# 2   2017    중구   51540   40523  3508   7294  215  78.624369  6.806364
# 3   2017   용산구   77458   67335  2783   7221  119  86.930982  3.592915
# 4   2017   성동구  103116   87762  3698  11459  197  85.109973  3.586252
# 5   2017   광진구   98631   82951  4169  11248  263  84.102361  4.226866
# 6   2017  동대문구   97507   79837  4249  13244  177  81.878224  4.357636
# 7   2017   중랑구  113916   92596  5305  15619  396  81.284455  4.656940
# 8   2017   성북구  117209  100028  5745  11311  125  85.341569  4.901501
# 9   2017   강북구   77820   63987  4268   9416  149  82.224364  5.484451
# 10  2017   도봉구   97323   82048  4129  10937  209  84.304841  4.242574
#
#        화물차 비율
# 1   10.759817
# 2   14.152115
# 3    9.322472
# 4   11.112727
# 5   11.404122
# 6   13.582615
# 7   13.710980
# 8    9.650283
# 9   12.099717
# 10  11.237837

# %%
# 노상비율, 노외비율, 건축물비율 계산필드 추가
df_par['노상 비율'] = (df_par['노상']/df_par['합계']) * 100
df_par['노외 비율'] = (df_par['노외']/df_par['합계']) * 100
df_par['건축물 비율'] = (df_par['건축물부설']/df_par['합계']) * 100
df_par.head()
# Out:
#      년도  자치구      합계    노상    노외   건축물부설     노상 비율     노외 비율     건축물 비율
# 1  2017  서울시  308025  8576  1977  297472   2.78419  0.641831  96.573979
# 2  2017  종로구    7220   148   103    6969  2.049861  1.426593  96.523546
# 3  2017   중구    4152   151    94    3907  3.636802  2.263969  94.099229
# 4  2017  용산구    7291   362    75    6854  4.965025  1.028665  94.006309
# 5  2017  성동구    6658   264    65    6329  3.965155  0.976269  95.058576

# %%
df_car1 = df_car

# %%
df_car1.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차     승용차 비율    승합차 비율     화물차 비율
# 1  2017  종로구   50828  41115  4055   5469  189  80.890454  7.977886  10.759817
# 2  2017   중구   51540  40523  3508   7294  215  78.624369  6.806364  14.152115
# 3  2017  용산구   77458  67335  2783   7221  119  86.930982  3.592915   9.322472
# 4  2017  성동구  103116  87762  3698  11459  197  85.109973  3.586252  11.112727
# 5  2017  광진구   98631  82951  4169  11248  263  84.102361  4.226866  11.404122

# %%
del df_car1['승용차 비율']

# %%
df_car1.head(3)
# Out:
#      년도  자치구     합계    승용차   승합차   화물차  특수차    승합차 비율     화물차 비율
# 1  2017  종로구  50828  41115  4055  5469  189  7.977886  10.759817
# 2  2017   중구  51540  40523  3508  7294  215  6.806364  14.152115
# 3  2017  용산구  77458  67335  2783  7221  119  3.592915   9.322472

# %%
df_car['승용차 비율'] = (df_car['승용차']/df_car['합계']) * 100

# %%
# 데이터 프레임 복사
df_car1=df_car.copy()
df_par1=df_par.copy()

# %%
# df_car1에 불필요한 필드
# 승용차, 승합차, 화물차, 특수차 삭제 
del df_car1['승용차']
del df_car1['승합차']
del df_car1['화물차']
del df_car1['특수차']
df_car1.head()
# Out:
#      년도  자치구      합계    승합차 비율     화물차 비율     승용차 비율
# 1  2017  종로구   50828  7.977886  10.759817  80.890454
# 2  2017   중구   51540  6.806364  14.152115  78.624369
# 3  2017  용산구   77458  3.592915   9.322472  86.930982
# 4  2017  성동구  103116  3.586252  11.112727  85.109973
# 5  2017  광진구   98631  4.226866  11.404122  84.102361

# %%
df_car.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차    승합차 비율     화물차 비율     승용차 비율
# 1  2017  종로구   50828  41115  4055   5469  189  7.977886  10.759817  80.890454
# 2  2017   중구   51540  40523  3508   7294  215  6.806364  14.152115  78.624369
# 3  2017  용산구   77458  67335  2783   7221  119  3.592915   9.322472  86.930982
# 4  2017  성동구  103116  87762  3698  11459  197  3.586252  11.112727  85.109973
# 5  2017  광진구   98631  82951  4169  11248  263  4.226866  11.404122  84.102361

# %%
del df_par1['노상']
del df_par1['노외']
del df_par1['건축물부설']
df_par1.head(2)
# Out:
#      년도  자치구      합계     노상 비율     노외 비율     건축물 비율
# 1  2017  서울시  308025   2.78419  0.641831  96.573979
# 2  2017  종로구    7220  2.049861  1.426593  96.523546

# %%
data_seoul = pd.merge(df_car1, df_par1, on="자치구")
data_seoul.head(2)
# Out:
#    년도_x  자치구   합계_x    승합차 비율     화물차 비율     승용차 비율  년도_y  합계_y     노상 비율  \
# 0  2017  종로구  50828  7.977886  10.759817  80.890454  2017  7220  2.049861
# 1  2017   중구  51540  6.806364  14.152115  78.624369  2017  4152  3.636802
#
#       노외 비율     건축물 비율
# 0  1.426593  96.523546
# 1  2.263969  94.099229

# %%
data_seoul.rename(columns={data_seoul.columns[0]: "년도",
                          data_seoul.columns[2]: "차량합계",
                          data_seoul.columns[7]: '주차장합계'},
                 inplace=True)
del data_seoul['년도_y']

#data_seoul에서 자치구를 인덱스 키로 변경합니다. 
data_seoul.set_index("자치구", inplace=True)
data_seoul.head()
# Out:
#        년도    차량합계    승합차 비율     화물차 비율     승용차 비율  주차장합계     노상 비율     노외 비율  \
# 자치구
# 종로구  2017   50828  7.977886  10.759817  80.890454   7220  2.049861  1.426593
# 중구   2017   51540  6.806364  14.152115  78.624369   4152  3.636802  2.263969
# 용산구  2017   77458  3.592915   9.322472  86.930982   7291  4.965025  1.028665
# 성동구  2017  103116  3.586252  11.112727  85.109973   6658  3.965155  0.976269
# 광진구  2017   98631  4.226866  11.404122  84.102361  16304  2.201914  0.429342
#
#         건축물 비율
# 자치구
# 종로구  96.523546
# 중구   94.099229
# 용산구  94.006309
# 성동구  95.058576
# 광진구  97.368744

# %%
# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
font_path = "c:/Windows/Fonts/malgun.ttf"   # 폰트파일 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 스타일 서식 지정
plt.style.use('ggplot')

data = data_seoul[['차량합계', '주차장합계']].plot(kind='bar', title='주차장', figsize=(12,4), legend=True, fontsize=12, color=['blue', 'orange'])

plt.show()

# %%
# matplotlib 한글 폰트 오류 문제 해결
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
font_path = "c:/Windows/Fonts/malgun.ttf"   # 폰트파일 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

data_seoul1 = data_seoul.loc[['강서구', '강남구', '서초구', '송파구', '영등포구', '동대문구', '종로구']]

# 스타일 서식 지정
plt.style.use('ggplot')

data = data_seoul1[['차량합계', '주차장합계']].plot(kind='bar', title='주차장', figsize=(12,4), legend=True, fontsize=12, color=['blue', 'orange'])

plt.show()
